# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt

import sys
import os
from os import listdir
from os.path import isfile, join
from tqdm import tqdm

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier, StackingClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.metrics import f1_score

from keras.models import Sequential
from keras.layers import Dense, Conv1D, MaxPooling1D, Dropout, LSTM
from keras.regularizers import l1, l2


module_path = os.path.abspath(os.path.join(os.pardir, os.pardir))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from src.transformers import LinearTransformation, ParabolicTransformation, TrigTransformation

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2





# Global Var
sliding_window_size = 20
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
full_data = pd.read_csv('../../data/train.csv')
test_data = pd.read_csv('../../data/test.csv')

# %%
def chunk_data(data, number_of_chunks):
    chunks = list()
    lst = np.linspace(0, len(data), number_of_chunks + 1, dtype = int)
    for start, stop in zip(lst[0:-1], lst[1:]):
        chunks.append(data[start:stop].copy())
    return chunks

# %%
train_chunks = chunk_data(full_data, 10)

lt = LinearTransformation()
pt = ParabolicTransformation()
tt = TrigTransformation(trig_function = 'sin')

tt.fit_transform(train_chunks[6], 300, 50, 4.95)
# Out:
# array([-1.3469311 , -1.4805622 , -1.22479331, ..., -1.3798622 ,
#        -2.0366311 , -1.2874    ])

# %%
train_chunks = chunk_data(full_data, 10)

lt = LinearTransformation()
pt = ParabolicTransformation()
tt = TrigTransformation(trig_function = 'sin')

train_chunks[1].loc[train_chunks[1].index[:100000], 'signal'] = lt.fit_transform(train_chunks[1][:100000], 3/10, -15)
train_chunks[6]['signal'] = tt.fit_transform(train_chunks[6], 300, 50, 4.95)
train_chunks[7]['signal'] = tt.fit_transform(train_chunks[7], 350, 50, 5.030)
train_chunks[8]['signal'] = tt.fit_transform(train_chunks[8], 400, 50, 4.974)
train_chunks[9]['signal'] = tt.fit_transform(train_chunks[9], 450, 50, 5.089)

plt.figure(figsize = (20, 10))
for i in train_chunks:
    plt.plot(i['time'], i['signal'])

# %%
test_chunks = chunk_data(test_data, 4)
test_chunks = chunk_data(test_chunks[0], 5) + chunk_data(test_chunks[1], 5) + test_chunks[2:]

test_chunks[0]['signal'] = lt.fit_transform(test_chunks[0], 3 / 10, -150)
test_chunks[1]['signal'] = lt.fit_transform(test_chunks[1], 3 / 10, -153)
test_chunks[4]['signal'] = lt.fit_transform(test_chunks[4], 3 / 10, -162)
test_chunks[6]['signal'] = lt.fit_transform(test_chunks[6], 3 / 10, -168)
test_chunks[7]['signal'] = lt.fit_transform(test_chunks[7], 3 / 10, -171)
test_chunks[8]['signal'] = lt.fit_transform(test_chunks[8], 3 / 10, -174)
test_chunks[10]['signal'] = tt.fit_transform(test_chunks[10], 600, 50, 4.925)

test_chunks = test_chunks[:10] + chunk_data(pd.concat(test_chunks[10:]), 10)

plt.figure(figsize = (20, 10))
for i in test_chunks:
    plt.plot(i['time'], i['signal'])

# %%
def _sliding_window(array, window_size, offset = 0):
    """
    offset = number of zeros added to the begining 
    """
    array = np.append(np.append(np.zeros(offset), array), np.zeros(window_size - offset))
    sliding_window_array = [array[0: -window_size]]
    for i in range(1, window_size):
        sliding_window_array = np.append(sliding_window_array, [array[i:i - window_size]], axis = 0)
    return sliding_window_array.T

def make_sliding_window(series, window_size):
    col_names = [series.name + str(i) for i in range(window_size)]
    return pd.DataFrame(_sliding_window(series, window_size, window_size // 2), columns = col_names)

def make_sliding_window_frame(data, window_size):
    sliding_window = make_sliding_window(data['signal'], window_size)
    sliding_window['open_channels'] = data['open_channels'].reset_index(drop = True)
    return sliding_window

# %%
a = pd.concat([train_chunks[0], train_chunks[1]])
make_sliding_window_frame(a, 10)

model5_data = pd.concat([train_chunks[4], train_chunks[9]])
model5_data = make_sliding_window_frame(model5_data, sliding_window_size)
model5_data
# Out:
#          signal0   signal1   signal2   signal3   signal4   signal5   signal6  \
# 0       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  7.119100
# ...          ...       ...       ...       ...       ...       ...       ...
# 999995  5.279130  5.116871  4.314911  3.834752  3.616993  4.507934  3.387374
# 999996  5.116871  4.314911  3.834752  3.616993  4.507934  3.387374  2.348115
# 999997  4.314911  3.834752  3.616993  4.507934  3.387374  2.348115  4.191256
# 999998  3.834752  3.616993  4.507934  3.387374  2.348115  4.191256  4.371096
# 999999  3.616993  4.507934  3.387374  2.348115  4.191256  4.371096  2.919237
#
#          signal7   signal8   signal9  ...  signal11  signal12  signal13  \
# 0       0.000000  0.000000  0.000000  ...  6.771200  6.927800  7.354100
# 1       0.000000  0.000000  7.119100  ...  6.927800  7.354100  7.419400
# 2       0.000000  7.119100  6.771200  ...  7.354100  7.419400  7.661000
# 3       7.119100  6.771200  6.927800  ...  7.419400  7.661000  6.548900
# 4       6.771200  6.927800  7.354100  ...  7.661000  6.548900  6.098900
# ...          ...       ...       ...  ...       ...       ...       ...
# 999995  2.348115  4.191256  4.371096  ...  2.697878  4.516319  5.639659
# 999996  4.191256  4.371096  2.919237  ...  4.516319  5.639659  5.379200
# 999997  4.371096  2.919237  2.697878  ...  5.639659  5.379200  0.000000
# 999998  2.919237  2.697878  4.516319  ...  5.379200  0.000000  0.000000
# 999999  2.697878  4.516319  5.639659  ...  0.000000  0.000000  0.000000
#
#         signal14  signal15  signal16  signal17  signal18  signal19  \
# 0         7.4194    7.6610    6.5489    6.0989    6.6409    6.7583
# 1         7.6610    6.5489    6.0989    6.6409    6.7583    6.8535
# 2         6.5489    6.0989    6.6409    6.7583    6.8535    7.8474
# 3         6.0989    6.6409    6.7583    6.8535    7.8474    7.4129
# 4         6.6409    6.7583    6.8535    7.8474    7.4129    7.3647
# ...          ...       ...       ...       ...       ...       ...
# 999995    5.3792    0.0000    0.0000    0.0000    0.0000    0.0000
# 999996    0.0000    0.0000    0.0000    0.0000    0.0000    0.0000
# 999997    0.0000    0.0000    0.0000    0.0000    0.0000    0.0000
# 999998    0.0000    0.0000    0.0000    0.0000    0.0000    0.0000
# 999999    0.0000    0.0000    0.0000    0.0000    0.0000    0.0000
#
#         open_channels
# 0                  10
# 1                  10
# 2                  10
# 3                  10
# 4                  10
# ...               ...
# 999995              7
# 999996              7
# 999997              8
# 999998              9
# 999999              9
#
# [1000000 rows x 21 columns]

# %%
#'''
def get_model(data):
    model = Sequential()
    model.add(Dense(22, input_dim = sliding_window_size, activation = 'relu'))
    model.add(Dense(33, activation = 'relu'))
    model.add(Dense(44, activation = 'relu'))
    model.add(Dense(11, activation = 'softmax'))
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    model.fit(data.drop(['open_channels'], axis = 1), data['open_channels'], batch_size = 100, epochs = 20)
    return model
#'''

'''
def get_model(data, time_window_size):
    model = Sequential()
    model.add(Conv1D(filters=128, kernel_size=5, padding='same', activation='relu',
                         input_shape=(time_window_size, 1)))
    model.add(MaxPooling1D(pool_size=5))
    model.add(Dense(units = time_window_size, activation='linear'))
    model.add(Dense(time_window_size * 2, activation = 'relu'))
    model.add(Dense(11, activation = 'softmax'))
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model
#'''

'''
def get_modelx(data, time_window_size):
    model = Sequential()
    model.add(LSTM(time_window_size * 10, input_shape  = (1, time_window_size)))
    model.add(Dense(40, activation = 'relu', kernel_regularizer = l2(0.01)))
    model.add(Dense(11, activation = 'softmax'))
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model
#''';

# %%
model1_data = pd.concat([train_chunks[0], train_chunks[1]])
model1_data = make_sliding_window_frame(model1_data, sliding_window_size)

model2_data = pd.concat([train_chunks[2], train_chunks[6]])
model2_data = make_sliding_window_frame(model2_data, sliding_window_size)

model3_data = pd.concat([train_chunks[3], train_chunks[7]])
model3_data = make_sliding_window_frame(model3_data, sliding_window_size)

model4_data = pd.concat([train_chunks[5], train_chunks[8]])
model4_data = make_sliding_window_frame(model4_data, sliding_window_size)

model5_data = pd.concat([train_chunks[4], train_chunks[9]])
model5_data = make_sliding_window_frame(model5_data, sliding_window_size)

# %%
model1 = get_model(model1_data)
model2 = get_model(model2_data)
model3 = get_model(model3_data)
model4 = get_model(model4_data)
model5 = get_model(model5_data)
# Out:
# Train on 600000 samples, validate on 400000 samples
# Epoch 1/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0168 - accuracy: 0.9944 - val_loss: 0.0042 - val_accuracy: 0.9984
# Epoch 2/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0033 - accuracy: 0.9989 - val_loss: 0.0013 - val_accuracy: 0.9996
# Epoch 3/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0027 - accuracy: 0.9990 - val_loss: 0.0014 - val_accuracy: 0.9995
# Epoch 4/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0026 - accuracy: 0.9991 - val_loss: 0.0015 - val_accuracy: 0.9995
# Epoch 5/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0023 - accuracy: 0.9992 - val_loss: 0.0028 - val_accuracy: 0.9990
# Epoch 6/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0022 - accuracy: 0.9992 - val_loss: 0.0017 - val_accuracy: 0.9994
# Epoch 7/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0022 - accuracy: 0.9993 - val_loss: 0.0013 - val_accuracy: 0.9995
# Epoch 8/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0017 - val_accuracy: 0.9994
# Epoch 9/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0019 - accuracy: 0.9993 - val_loss: 0.0012 - val_accuracy: 0.9996
# Epoch 10/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.0023 - val_accuracy: 0.9992
# Epoch 11/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0019 - accuracy: 0.9993 - val_loss: 0.0016 - val_accuracy: 0.9994
# Epoch 12/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.0042 - val_accuracy: 0.9986
# Epoch 13/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.0010 - val_accuracy: 0.9997
# Epoch 14/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.0014 - val_accuracy: 0.9995
# Epoch 15/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0017 - accuracy: 0.9994 - val_loss: 0.0015 - val_accuracy: 0.9995
# Epoch 16/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0017 - accuracy: 0.9994 - val_loss: 0.0020 - val_accuracy: 0.9993
# Epoch 17/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0017 - accuracy: 0.9994 - val_loss: 0.0012 - val_accuracy: 0.9996
# Epoch 18/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0011 - val_accuracy: 0.9996
# Epoch 19/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0017 - accuracy: 0.9994 - val_loss: 0.0019 - val_accuracy: 0.9993
# Epoch 20/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0016 - accuracy: 0.9994 - val_loss: 0.0011 - val_accuracy: 0.9997
# Train on 600000 samples, validate on 400000 samples
# Epoch 1/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0462 - accuracy: 0.9848 - val_loss: 0.0153 - val_accuracy: 0.9946
# Epoch 2/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0179 - accuracy: 0.9936 - val_loss: 0.0161 - val_accuracy: 0.9942
# Epoch 3/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0166 - accuracy: 0.9940 - val_loss: 0.0148 - val_accuracy: 0.9948
# Epoch 4/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0155 - accuracy: 0.9945 - val_loss: 0.0149 - val_accuracy: 0.9948
# Epoch 5/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0145 - accuracy: 0.9948 - val_loss: 0.0160 - val_accuracy: 0.9940
# Epoch 6/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0136 - accuracy: 0.9951 - val_loss: 0.0194 - val_accuracy: 0.9931
# Epoch 7/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0130 - accuracy: 0.9954 - val_loss: 0.0126 - val_accuracy: 0.9955
# Epoch 8/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0125 - accuracy: 0.9956 - val_loss: 0.0179 - val_accuracy: 0.9938
# Epoch 9/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0120 - accuracy: 0.9957 - val_loss: 0.0127 - val_accuracy: 0.9955
# Epoch 10/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0118 - accuracy: 0.9959 - val_loss: 0.0125 - val_accuracy: 0.9955
# Epoch 11/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0115 - accuracy: 0.9960 - val_loss: 0.0111 - val_accuracy: 0.9961
# Epoch 12/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0112 - accuracy: 0.9960 - val_loss: 0.0124 - val_accuracy: 0.9956
# Epoch 13/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0111 - accuracy: 0.9961 - val_loss: 0.0143 - val_accuracy: 0.9948
# Epoch 14/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0109 - accuracy: 0.9961 - val_loss: 0.0233 - val_accuracy: 0.9917
# Epoch 15/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0108 - accuracy: 0.9961 - val_loss: 0.0125 - val_accuracy: 0.9956
# Epoch 16/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0106 - accuracy: 0.9962 - val_loss: 0.0146 - val_accuracy: 0.9947
# Epoch 17/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0106 - accuracy: 0.9962 - val_loss: 0.0194 - val_accuracy: 0.9931
# Epoch 18/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0104 - accuracy: 0.9962 - val_loss: 0.0110 - val_accuracy: 0.9960
# Epoch 19/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0103 - accuracy: 0.9963 - val_loss: 0.0116 - val_accuracy: 0.9959
# Epoch 20/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0101 - accuracy: 0.9964 - val_loss: 0.0130 - val_accuracy: 0.9954
# Train on 600000 samples, validate on 400000 samples
# Epoch 1/20
# 600000/600000 [==============================] - 8s 13us/step - loss: 0.1071 - accuracy: 0.9626 - val_loss: 0.8404 - val_accuracy: 0.9336
# Epoch 2/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0605 - accuracy: 0.9778 - val_loss: 0.8767 - val_accuracy: 0.9312
# Epoch 3/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0579 - accuracy: 0.9789 - val_loss: 0.8830 - val_accuracy: 0.9350
# Epoch 4/20
# 600000/600000 [==============================] - 8s 13us/step - loss: 0.0558 - accuracy: 0.9795 - val_loss: 0.9396 - val_accuracy: 0.9384
# Epoch 5/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0546 - accuracy: 0.9800 - val_loss: 0.9414 - val_accuracy: 0.9343
# Epoch 6/20
# 600000/600000 [==============================] - 515s 859us/step - loss: 0.0534 - accuracy: 0.9805 - val_loss: 1.0034 - val_accuracy: 0.9337
# Epoch 7/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0524 - accuracy: 0.9810 - val_loss: 1.0376 - val_accuracy: 0.9338
# Epoch 8/20
# 600000/600000 [==============================] - 7s 11us/step - loss: 0.0521 - accuracy: 0.9809 - val_loss: 1.0335 - val_accuracy: 0.9396
# Epoch 9/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0514 - accuracy: 0.9811 - val_loss: 1.0892 - val_accuracy: 0.9427
# Epoch 10/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0511 - accuracy: 0.9813 - val_loss: 1.1532 - val_accuracy: 0.9408
# Epoch 11/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0508 - accuracy: 0.9815 - val_loss: 1.2095 - val_accuracy: 0.9393
# Epoch 12/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0503 - accuracy: 0.9815 - val_loss: 1.2613 - val_accuracy: 0.9400
# Epoch 13/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0501 - accuracy: 0.9818 - val_loss: 1.1611 - val_accuracy: 0.9393
# Epoch 14/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0501 - accuracy: 0.9816 - val_loss: 1.2094 - val_accuracy: 0.9390
# Epoch 15/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0498 - accuracy: 0.9818 - val_loss: 1.2674 - val_accuracy: 0.9378
# Epoch 16/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0498 - accuracy: 0.9818 - val_loss: 1.2752 - val_accuracy: 0.9410
# Epoch 17/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0495 - accuracy: 0.9819 - val_loss: 1.2376 - val_accuracy: 0.9385
# Epoch 18/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0492 - accuracy: 0.9821 - val_loss: 1.3127 - val_accuracy: 0.9368
# Epoch 19/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0492 - accuracy: 0.9819 - val_loss: 1.3031 - val_accuracy: 0.9379
# Epoch 20/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0491 - accuracy: 0.9821 - val_loss: 1.3602 - val_accuracy: 0.9373
# Train on 600000 samples, validate on 400000 samples
# Epoch 1/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.1617 - accuracy: 0.9398 - val_loss: 0.1119 - val_accuracy: 0.9574
# Epoch 2/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0959 - accuracy: 0.9643 - val_loss: 0.1030 - val_accuracy: 0.9611
# Epoch 3/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0927 - accuracy: 0.9654 - val_loss: 0.1242 - val_accuracy: 0.9531
# Epoch 4/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0904 - accuracy: 0.9663 - val_loss: 0.0954 - val_accuracy: 0.9640
# Epoch 5/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0896 - accuracy: 0.9667 - val_loss: 0.1185 - val_accuracy: 0.9555
# Epoch 6/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0886 - accuracy: 0.9671 - val_loss: 0.1126 - val_accuracy: 0.9571
# Epoch 7/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0877 - accuracy: 0.9674 - val_loss: 0.0991 - val_accuracy: 0.9628
# Epoch 8/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0872 - accuracy: 0.9677 - val_loss: 0.0993 - val_accuracy: 0.9623
# Epoch 9/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0864 - accuracy: 0.9677 - val_loss: 0.0994 - val_accuracy: 0.9630
# Epoch 10/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0859 - accuracy: 0.9683 - val_loss: 0.0995 - val_accuracy: 0.9627
# Epoch 11/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0851 - accuracy: 0.9687 - val_loss: 0.1037 - val_accuracy: 0.9609
# Epoch 12/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0850 - accuracy: 0.9685 - val_loss: 0.0997 - val_accuracy: 0.9630
# Epoch 13/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0845 - accuracy: 0.9688 - val_loss: 0.1027 - val_accuracy: 0.9613
# Epoch 14/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0840 - accuracy: 0.9691 - val_loss: 0.0964 - val_accuracy: 0.9642
# Epoch 15/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0837 - accuracy: 0.9693 - val_loss: 0.1072 - val_accuracy: 0.9598
# Epoch 16/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0833 - accuracy: 0.9692 - val_loss: 0.0947 - val_accuracy: 0.9645
# Epoch 17/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0832 - accuracy: 0.9695 - val_loss: 0.1361 - val_accuracy: 0.9484
# Epoch 18/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0830 - accuracy: 0.9695 - val_loss: 0.0919 - val_accuracy: 0.9659
# Epoch 19/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0825 - accuracy: 0.9695 - val_loss: 0.1045 - val_accuracy: 0.9610
# Epoch 20/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.0825 - accuracy: 0.9697 - val_loss: 0.0927 - val_accuracy: 0.9653
# Train on 600000 samples, validate on 400000 samples
# Epoch 1/20
# 600000/600000 [==============================] - 8s 13us/step - loss: 0.4440 - accuracy: 0.8203 - val_loss: 0.3814 - val_accuracy: 0.8459
# Epoch 2/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.3311 - accuracy: 0.8670 - val_loss: 0.3218 - val_accuracy: 0.8718
# Epoch 3/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.3259 - accuracy: 0.8694 - val_loss: 0.3655 - val_accuracy: 0.8522
# Epoch 4/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.3241 - accuracy: 0.8702 - val_loss: 0.3596 - val_accuracy: 0.8543
# Epoch 5/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.3220 - accuracy: 0.8709 - val_loss: 0.3620 - val_accuracy: 0.8528
# Epoch 6/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.3202 - accuracy: 0.8719 - val_loss: 0.3636 - val_accuracy: 0.8530
# Epoch 7/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.3188 - accuracy: 0.8722 - val_loss: 0.3389 - val_accuracy: 0.8638
# Epoch 8/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.3181 - accuracy: 0.8726 - val_loss: 0.3548 - val_accuracy: 0.8563
# Epoch 9/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.3168 - accuracy: 0.8733 - val_loss: 0.4179 - val_accuracy: 0.8298
# Epoch 10/20
# 600000/600000 [==============================] - 8s 13us/step - loss: 0.3162 - accuracy: 0.8731 - val_loss: 0.3776 - val_accuracy: 0.8460
# Epoch 11/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.3154 - accuracy: 0.8737 - val_loss: 0.3702 - val_accuracy: 0.8492
# Epoch 12/20
# 600000/600000 [==============================] - 8s 13us/step - loss: 0.3146 - accuracy: 0.8741 - val_loss: 0.3736 - val_accuracy: 0.8485
# Epoch 13/20
# 600000/600000 [==============================] - 8s 13us/step - loss: 0.3147 - accuracy: 0.8738 - val_loss: 0.3827 - val_accuracy: 0.8445
# Epoch 14/20
# 600000/600000 [==============================] - 8s 13us/step - loss: 0.3141 - accuracy: 0.8745 - val_loss: 0.3896 - val_accuracy: 0.8413
# Epoch 15/20
# 600000/600000 [==============================] - 8s 13us/step - loss: 0.3135 - accuracy: 0.8741 - val_loss: 0.3521 - val_accuracy: 0.8583
# Epoch 16/20
# 600000/600000 [==============================] - 8s 13us/step - loss: 0.3134 - accuracy: 0.8742 - val_loss: 0.3407 - val_accuracy: 0.8620
# Epoch 17/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.3129 - accuracy: 0.8745 - val_loss: 0.3355 - val_accuracy: 0.8646
# Epoch 18/20
# 600000/600000 [==============================] - 8s 13us/step - loss: 0.3123 - accuracy: 0.8750 - val_loss: 0.4259 - val_accuracy: 0.8265
# Epoch 19/20
# 600000/600000 [==============================] - 8s 13us/step - loss: 0.3126 - accuracy: 0.8749 - val_loss: 0.3743 - val_accuracy: 0.8468
# Epoch 20/20
# 600000/600000 [==============================] - 7s 12us/step - loss: 0.3124 - accuracy: 0.8749 - val_loss: 0.3931 - val_accuracy: 0.8388

# %%
def predict(model, test_data):
    y_predictions = model.predict_classes(make_sliding_window(test_data['signal'], sliding_window_size))
    return pd.DataFrame({'time' : test_data['time'].values, 'open_channels' : y_predictions})

# %%
predictions = pd.DataFrame(columns = ['time', 'open_channels'])
predictions = pd.concat([predictions, predict(model1, test_chunks[0])])
predictions = pd.concat([predictions, predict(model3, test_chunks[1])])
predictions = pd.concat([predictions, predict(model4, test_chunks[2])])
predictions = pd.concat([predictions, predict(model1, test_chunks[3])])
predictions = pd.concat([predictions, predict(model2, test_chunks[4])])
predictions = pd.concat([predictions, predict(model5, test_chunks[5])])
predictions = pd.concat([predictions, predict(model4, test_chunks[6])])
predictions = pd.concat([predictions, predict(model5, test_chunks[7])])
predictions = pd.concat([predictions, predict(model1, test_chunks[8])])
predictions = pd.concat([predictions, predict(model3, test_chunks[9])])
predictions = pd.concat([predictions, predict(model1, test_chunks[10])])
predictions = pd.concat([predictions, predict(model1, test_chunks[11])])
predictions = pd.concat([predictions, predict(model1, test_chunks[12])])
predictions = pd.concat([predictions, predict(model1, test_chunks[13])])
predictions = pd.concat([predictions, predict(model1, test_chunks[14])])
predictions = pd.concat([predictions, predict(model1, test_chunks[15])])
predictions = pd.concat([predictions, predict(model1, test_chunks[16])])
predictions = pd.concat([predictions, predict(model1, test_chunks[17])])
predictions = pd.concat([predictions, predict(model1, test_chunks[18])])
predictions = pd.concat([predictions, predict(model1, test_chunks[19])])

# %%
plt.figure(figsize = (20, 10))
plt.plot(predictions['time'], predictions['open_channels'].rolling(10000).mean() + 10)
for i in test_chunks:
    plt.plot(i['time'], i['signal'])

# %%
predictions.to_csv('~/Desktop/test_predictions.csv', index = False, float_format='%.4f')
#0.937 preds_09

# %%
model5 = get_model(model5_data)
y =  model5_data['open_channels']
X = model5_data.drop(['open_channels'], axis = 1)
#X = X.to_numpy().reshape((X.shape[0], X.shape[1], 1))
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
history = model5.fit(X_train, y_train, batch_size = 100, epochs = 5, validation_split = 0.4)
# Out:
# Train on 450000 samples, validate on 300000 samples
# Epoch 1/5
# 450000/450000 [==============================] - 5s 12us/step - loss: 0.3354 - accuracy: 0.8652 - val_loss: 0.3276 - val_accuracy: 0.8683
# Epoch 2/5
# 450000/450000 [==============================] - 5s 12us/step - loss: 0.3341 - accuracy: 0.8660 - val_loss: 0.3286 - val_accuracy: 0.8677
# Epoch 3/5
# 450000/450000 [==============================] - 5s 12us/step - loss: 0.3330 - accuracy: 0.8663 - val_loss: 0.3267 - val_accuracy: 0.8686
# Epoch 4/5
# 450000/450000 [==============================] - 5s 12us/step - loss: 0.3325 - accuracy: 0.8662 - val_loss: 0.3416 - val_accuracy: 0.8614
# Epoch 5/5
# 450000/450000 [==============================] - 5s 12us/step - loss: 0.3314 - accuracy: 0.8670 - val_loss: 0.3364 - val_accuracy: 0.8651

# %%
f1_score(y_test, model5.predict_classes(X_test), average = 'macro')
# Out:
# 0.8477729903969655

# %%
model5.predict_classes(X_test)
# Out:
# array([10,  8,  8, ...,  7,  6,  5])

# %%
sys.getsizeof(frame) // 1000000
# Out:
# 88
