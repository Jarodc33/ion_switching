# %%
import pandas as pd
import numpy as np
import math
import random
import matplotlib.pyplot as plt

import sys
import os
from os import listdir
from os.path import isfile, join
from tqdm import tqdm
import time

from sklearn.model_selection import train_test_split, KFold, GroupKFold
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier, StackingClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.metrics import f1_score

from keras.models import Sequential
from keras.layers import Dense, Conv1D, MaxPooling1D, Dropout, LSTM
from keras.regularizers import l1, l2, l1_l2
from keras.models import load_model


module_path = os.path.abspath(os.path.join(os.pardir, os.pardir))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from src.transformers import LinearTransformation, ParabolicTransformation, TrigTransformation
from src.preprocessing import *
from src.sliding_window import *
from src.models import *

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2


# Global Var
sliding_window_size = 20
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
full_data = pd.read_csv('../../data/train.csv')
test_data = pd.read_csv('../../data/test.csv')

# %%
train_chunks = chunk_data(full_data, 10)

lt = LinearTransformation()
pt = ParabolicTransformation()
tt = TrigTransformation(trig_function = 'sin')

train_chunks[1].loc[train_chunks[1].index[:100000], 'signal'] = lt.fit_transform(train_chunks[1][:100000], 3/10, -15)
train_chunks[6]['signal'] = tt.fit_transform(train_chunks[6], 300, 50, 4.95)
train_chunks[7]['signal'] = tt.fit_transform(train_chunks[7], 350, 50, 5.030)
train_chunks[8]['signal'] = tt.fit_transform(train_chunks[8], 400, 50, 4.974)
train_chunks[9]['signal'] = tt.fit_transform(train_chunks[9], 450, 50, 5.089)

plt.figure(figsize = (20, 10))
for i in train_chunks:
    plt.plot(i['time'], i['signal'])

# %%
test_chunks = chunk_data(test_data, 4)
test_chunks = chunk_data(test_chunks[0], 5) + chunk_data(test_chunks[1], 5) + test_chunks[2:]

test_chunks[0]['signal'] = lt.fit_transform(test_chunks[0], 3 / 10, -150)
test_chunks[1]['signal'] = lt.fit_transform(test_chunks[1], 3 / 10, -153)
test_chunks[4]['signal'] = lt.fit_transform(test_chunks[4], 3 / 10, -162)
test_chunks[6]['signal'] = lt.fit_transform(test_chunks[6], 3 / 10, -168)
test_chunks[7]['signal'] = lt.fit_transform(test_chunks[7], 3 / 10, -171)
test_chunks[8]['signal'] = lt.fit_transform(test_chunks[8], 3 / 10, -174)
test_chunks[10]['signal'] = tt.fit_transform(test_chunks[10], 600, 50, 4.925)

test_chunks = test_chunks[:10] + chunk_data(pd.concat(test_chunks[10:]), 10)

plt.figure(figsize = (20, 10))
for i in test_chunks:
    plt.plot(i['time'], i['signal'])

# %%
#model = get_model(model5_data, cycles = 20, epochs = 2)

# %% [markdown]
# y = model5_data['open_channels']
# X = model5_data.drop(['open_channels'], axis = 1)
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.35)
# model.fit(X_train, y_train, batch_size = 100, epochs = 3, validation_data = (X_test, y_test))

# %% [markdown]
# y = model5_data['open_channels']
# X = model5_data.drop(['open_channels'], axis = 1)
# X_train, X_test, y_train, y_test = train_test_split(X, y)
# model.fit(X_train, y_train, batch_size = 100, epochs = 3, validation_data = (X_test, y_test))

# %%
model1_data = pd.concat([train_chunks[0], train_chunks[1]])
model1_data = make_sliding_window_frame(model1_data, sliding_window_size)

model2_data = pd.concat([train_chunks[2], train_chunks[6]])
model2_data = make_sliding_window_frame(model2_data, sliding_window_size)

model3_data = pd.concat([train_chunks[3]])
# model3_data = pd.concat([train_chunks[3], train_chunks[7]])
model3_data = make_sliding_window_frame(model3_data, sliding_window_size)

model4_data = pd.concat([train_chunks[5], train_chunks[8]])
model4_data = make_sliding_window_frame(model4_data, sliding_window_size)

model5_data = pd.concat([train_chunks[4], train_chunks[9]])
model5_data = make_sliding_window_frame(model5_data, sliding_window_size)

# %%
model1_data.shape
# Out:
# (1000000, 21)

# %%
nn = BasicNN(sliding_window_size)
model1 = nn.get_trained_model(model1_data, cycles = 8, epochs = 2)
print('\n\n')
time.sleep(300)
model2 = nn.get_trained_model(model2_data, cycles = 8, epochs = 2)
print('\n\n')
time.sleep(300)
model3 = nn.get_trained_model(model3_data, cycles = 10, epochs = 2)
print('\n\n')
time.sleep(300)
model4 = nn.get_trained_model(model4_data, cycles = 15, epochs = 2)
print('\n\n')
time.sleep(300)
model5 = nn.get_trained_model(model5_data, cycles = 20, epochs = 2)
# Out:
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.0166 - accuracy: 0.9949 - val_loss: 0.0020 - val_accuracy: 0.9994
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0028 - accuracy: 0.9990 - val_loss: 0.0019 - val_accuracy: 0.9994
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0026 - accuracy: 0.9991 - val_loss: 0.0014 - val_accuracy: 0.9996
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0022 - accuracy: 0.9993 - val_loss: 0.0017 - val_accuracy: 0.9995
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 12us/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0027 - val_accuracy: 0.9991
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.0015 - val_accuracy: 0.9995
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.0020 - val_accuracy: 0.9993
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.0014 - val_accuracy: 0.9995
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.0012 - val_accuracy: 0.9996
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0017 - accuracy: 0.9994 - val_loss: 0.0021 - val_accuracy: 0.9994
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.0011 - val_accuracy: 0.9996
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0025 - val_accuracy: 0.9991
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.0017 - accuracy: 0.9994 - val_loss: 0.0012 - val_accuracy: 0.9996
# Epoch 2/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.0012 - val_accuracy: 0.9996
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 8s 13us/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.0013 - val_accuracy: 0.9996
# Epoch 2/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.0014 - val_accuracy: 0.9995
#
#
#
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.0383 - accuracy: 0.9870 - val_loss: 0.0126 - val_accuracy: 0.9955
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0109 - accuracy: 0.9961 - val_loss: 0.0086 - val_accuracy: 0.9970
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0108 - accuracy: 0.9962 - val_loss: 0.0080 - val_accuracy: 0.9973
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0104 - accuracy: 0.9962 - val_loss: 0.0116 - val_accuracy: 0.9957
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0099 - accuracy: 0.9965 - val_loss: 0.0082 - val_accuracy: 0.9970
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0096 - accuracy: 0.9966 - val_loss: 0.0084 - val_accuracy: 0.9969
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0093 - accuracy: 0.9966 - val_loss: 0.0107 - val_accuracy: 0.9961
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0091 - accuracy: 0.9968 - val_loss: 0.0122 - val_accuracy: 0.9958
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0093 - accuracy: 0.9967 - val_loss: 0.0078 - val_accuracy: 0.9973
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0088 - accuracy: 0.9969 - val_loss: 0.0073 - val_accuracy: 0.9975
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.0089 - accuracy: 0.9968 - val_loss: 0.0084 - val_accuracy: 0.9970
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0089 - accuracy: 0.9969 - val_loss: 0.0074 - val_accuracy: 0.9973
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.0085 - accuracy: 0.9969 - val_loss: 0.0075 - val_accuracy: 0.9974
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0083 - accuracy: 0.9970 - val_loss: 0.0074 - val_accuracy: 0.9974
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0083 - accuracy: 0.9971 - val_loss: 0.0081 - val_accuracy: 0.9972
# Epoch 2/2
# 650000/650000 [==============================] - 7s 12us/step - loss: 0.0083 - accuracy: 0.9970 - val_loss: 0.0080 - val_accuracy: 0.9973
#
#
#
# Train on 325000 samples, validate on 175000 samples
# Epoch 1/2
# 325000/325000 [==============================] - 4s 12us/step - loss: 0.1200 - accuracy: 0.9608 - val_loss: 0.0494 - val_accuracy: 0.9824
# Epoch 2/2
# 325000/325000 [==============================] - 4s 11us/step - loss: 0.0410 - accuracy: 0.9852 - val_loss: 0.0372 - val_accuracy: 0.9866
# Train on 325000 samples, validate on 175000 samples
# Epoch 1/2
# 325000/325000 [==============================] - 4s 11us/step - loss: 0.0389 - accuracy: 0.9861 - val_loss: 0.0361 - val_accuracy: 0.9871
# Epoch 2/2
# 325000/325000 [==============================] - 4s 11us/step - loss: 0.0375 - accuracy: 0.9863 - val_loss: 0.0352 - val_accuracy: 0.9874
# Train on 325000 samples, validate on 175000 samples
# Epoch 1/2
# 325000/325000 [==============================] - 4s 11us/step - loss: 0.0365 - accuracy: 0.9867 - val_loss: 0.0354 - val_accuracy: 0.9872
# Epoch 2/2
# 325000/325000 [==============================] - 4s 11us/step - loss: 0.0359 - accuracy: 0.9870 - val_loss: 0.0397 - val_accuracy: 0.9855
# Train on 325000 samples, validate on 175000 samples
# Epoch 1/2
# 325000/325000 [==============================] - 4s 11us/step - loss: 0.0359 - accuracy: 0.9870 - val_loss: 0.0359 - val_accuracy: 0.9870
# Epoch 2/2
# 325000/325000 [==============================] - 4s 11us/step - loss: 0.0354 - accuracy: 0.9872 - val_loss: 0.0389 - val_accuracy: 0.9860
# Train on 325000 samples, validate on 175000 samples
# Epoch 1/2
# 325000/325000 [==============================] - 4s 11us/step - loss: 0.0348 - accuracy: 0.9874 - val_loss: 0.0350 - val_accuracy: 0.9873
# Epoch 2/2
# 325000/325000 [==============================] - 4s 11us/step - loss: 0.0346 - accuracy: 0.9874 - val_loss: 0.0369 - val_accuracy: 0.9866
# Train on 325000 samples, validate on 175000 samples
# Epoch 1/2
# 325000/325000 [==============================] - 4s 11us/step - loss: 0.0350 - accuracy: 0.9872 - val_loss: 0.0355 - val_accuracy: 0.9870
# Epoch 2/2
# 325000/325000 [==============================] - 4s 11us/step - loss: 0.0347 - accuracy: 0.9873 - val_loss: 0.0342 - val_accuracy: 0.9877
# Train on 325000 samples, validate on 175000 samples
# Epoch 1/2
# 325000/325000 [==============================] - 4s 11us/step - loss: 0.0342 - accuracy: 0.9875 - val_loss: 0.0366 - val_accuracy: 0.9869
# Epoch 2/2
# 325000/325000 [==============================] - 4s 11us/step - loss: 0.0339 - accuracy: 0.9876 - val_loss: 0.0359 - val_accuracy: 0.9870
# Train on 325000 samples, validate on 175000 samples
# Epoch 1/2
# 325000/325000 [==============================] - 4s 11us/step - loss: 0.0342 - accuracy: 0.9876 - val_loss: 0.0334 - val_accuracy: 0.9878
# Epoch 2/2
# 325000/325000 [==============================] - 4s 11us/step - loss: 0.0338 - accuracy: 0.9878 - val_loss: 0.0341 - val_accuracy: 0.9876
# Train on 325000 samples, validate on 175000 samples
# Epoch 1/2
# 325000/325000 [==============================] - 4s 12us/step - loss: 0.0338 - accuracy: 0.9879 - val_loss: 0.0348 - val_accuracy: 0.9874
# Epoch 2/2
# 325000/325000 [==============================] - 4s 11us/step - loss: 0.0336 - accuracy: 0.9877 - val_loss: 0.0338 - val_accuracy: 0.9876
# Train on 325000 samples, validate on 175000 samples
# Epoch 1/2
# 325000/325000 [==============================] - 4s 11us/step - loss: 0.0330 - accuracy: 0.9879 - val_loss: 0.0343 - val_accuracy: 0.9879
# Epoch 2/2
# 325000/325000 [==============================] - 4s 12us/step - loss: 0.0327 - accuracy: 0.9880 - val_loss: 0.0351 - val_accuracy: 0.9875
#
#
#
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.1433 - accuracy: 0.9469 - val_loss: 0.0755 - val_accuracy: 0.9722
# Epoch 2/2
# 650000/650000 [==============================] - 7s 12us/step - loss: 0.0745 - accuracy: 0.9728 - val_loss: 0.0685 - val_accuracy: 0.9748
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 12us/step - loss: 0.0720 - accuracy: 0.9735 - val_loss: 0.0725 - val_accuracy: 0.9733
# Epoch 2/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.0702 - accuracy: 0.9743 - val_loss: 0.0770 - val_accuracy: 0.9719
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.0696 - accuracy: 0.9744 - val_loss: 0.0679 - val_accuracy: 0.9750
# Epoch 2/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.0683 - accuracy: 0.9750 - val_loss: 0.0660 - val_accuracy: 0.9760
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.0683 - accuracy: 0.9749 - val_loss: 0.0663 - val_accuracy: 0.9756
# Epoch 2/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.0679 - accuracy: 0.9752 - val_loss: 0.0642 - val_accuracy: 0.9766
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.0675 - accuracy: 0.9751 - val_loss: 0.0647 - val_accuracy: 0.9767
# Epoch 2/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.0670 - accuracy: 0.9753 - val_loss: 0.0631 - val_accuracy: 0.9772
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.0670 - accuracy: 0.9754 - val_loss: 0.0638 - val_accuracy: 0.9764
# Epoch 2/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.0666 - accuracy: 0.9757 - val_loss: 0.0709 - val_accuracy: 0.9741
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.0663 - accuracy: 0.9756 - val_loss: 0.0653 - val_accuracy: 0.9761
# Epoch 2/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.0656 - accuracy: 0.9759 - val_loss: 0.0653 - val_accuracy: 0.9761
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.0656 - accuracy: 0.9761 - val_loss: 0.0643 - val_accuracy: 0.9764
# Epoch 2/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.0655 - accuracy: 0.9761 - val_loss: 0.0641 - val_accuracy: 0.9763
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.0653 - accuracy: 0.9760 - val_loss: 0.0645 - val_accuracy: 0.9763
# Epoch 2/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.0650 - accuracy: 0.9762 - val_loss: 0.0636 - val_accuracy: 0.9769
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.0649 - accuracy: 0.9763 - val_loss: 0.0647 - val_accuracy: 0.9762
# Epoch 2/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.0649 - accuracy: 0.9764 - val_loss: 0.0674 - val_accuracy: 0.9752
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.0646 - accuracy: 0.9762 - val_loss: 0.0626 - val_accuracy: 0.9771
# Epoch 2/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.0645 - accuracy: 0.9764 - val_loss: 0.0655 - val_accuracy: 0.9762
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.0646 - accuracy: 0.9762 - val_loss: 0.0638 - val_accuracy: 0.9763
# Epoch 2/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.0644 - accuracy: 0.9765 - val_loss: 0.0675 - val_accuracy: 0.9753
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.0641 - accuracy: 0.9765 - val_loss: 0.0637 - val_accuracy: 0.9765
# Epoch 2/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.0642 - accuracy: 0.9766 - val_loss: 0.0631 - val_accuracy: 0.9769
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.0641 - accuracy: 0.9765 - val_loss: 0.0657 - val_accuracy: 0.9762
# Epoch 2/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.0637 - accuracy: 0.9765 - val_loss: 0.0632 - val_accuracy: 0.9769
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.0643 - accuracy: 0.9764 - val_loss: 0.0658 - val_accuracy: 0.9756
# Epoch 2/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.0642 - accuracy: 0.9765 - val_loss: 0.0644 - val_accuracy: 0.9765
#
#
#
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.4169 - accuracy: 0.8333 - val_loss: 0.3227 - val_accuracy: 0.8710
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.3134 - accuracy: 0.8751 - val_loss: 0.3171 - val_accuracy: 0.8740
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.3087 - accuracy: 0.8772 - val_loss: 0.3052 - val_accuracy: 0.8781
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.3054 - accuracy: 0.8780 - val_loss: 0.3098 - val_accuracy: 0.8763
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.3029 - accuracy: 0.8791 - val_loss: 0.3050 - val_accuracy: 0.8782
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.3013 - accuracy: 0.8799 - val_loss: 0.2957 - val_accuracy: 0.8829
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.3000 - accuracy: 0.8804 - val_loss: 0.2999 - val_accuracy: 0.8805
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.2989 - accuracy: 0.8810 - val_loss: 0.2918 - val_accuracy: 0.8838
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.2979 - accuracy: 0.8816 - val_loss: 0.2941 - val_accuracy: 0.8831
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.2964 - accuracy: 0.8819 - val_loss: 0.2898 - val_accuracy: 0.8848
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.2966 - accuracy: 0.8820 - val_loss: 0.2916 - val_accuracy: 0.8843
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.2959 - accuracy: 0.8823 - val_loss: 0.2941 - val_accuracy: 0.8825
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.2951 - accuracy: 0.8826 - val_loss: 0.2941 - val_accuracy: 0.8831
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.2941 - accuracy: 0.8830 - val_loss: 0.2925 - val_accuracy: 0.8838
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.2953 - accuracy: 0.8825 - val_loss: 0.2884 - val_accuracy: 0.8857
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.2944 - accuracy: 0.8830 - val_loss: 0.2870 - val_accuracy: 0.8866
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.2932 - accuracy: 0.8832 - val_loss: 0.2897 - val_accuracy: 0.8848
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.2939 - accuracy: 0.8828 - val_loss: 0.3035 - val_accuracy: 0.8791
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.2923 - accuracy: 0.8840 - val_loss: 0.2941 - val_accuracy: 0.8831
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.2919 - accuracy: 0.8840 - val_loss: 0.2899 - val_accuracy: 0.8849
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.2924 - accuracy: 0.8837 - val_loss: 0.2912 - val_accuracy: 0.8845
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.2916 - accuracy: 0.8842 - val_loss: 0.2905 - val_accuracy: 0.8850
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.2926 - accuracy: 0.8839 - val_loss: 0.2906 - val_accuracy: 0.8840
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.2922 - accuracy: 0.8839 - val_loss: 0.2877 - val_accuracy: 0.8853
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.2918 - accuracy: 0.8839 - val_loss: 0.2905 - val_accuracy: 0.8845
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.2915 - accuracy: 0.8841 - val_loss: 0.2885 - val_accuracy: 0.8853
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.2914 - accuracy: 0.8844 - val_loss: 0.2909 - val_accuracy: 0.8842
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.2913 - accuracy: 0.8841 - val_loss: 0.2930 - val_accuracy: 0.8833
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.2913 - accuracy: 0.8838 - val_loss: 0.2929 - val_accuracy: 0.8837
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.2910 - accuracy: 0.8844 - val_loss: 0.2869 - val_accuracy: 0.8863
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.2916 - accuracy: 0.8843 - val_loss: 0.2940 - val_accuracy: 0.8828
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.2913 - accuracy: 0.8842 - val_loss: 0.2865 - val_accuracy: 0.8863
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.2910 - accuracy: 0.8844 - val_loss: 0.2889 - val_accuracy: 0.8849
# Epoch 2/2
# 650000/650000 [==============================] - 7s 12us/step - loss: 0.2906 - accuracy: 0.8845 - val_loss: 0.2908 - val_accuracy: 0.8842
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.2907 - accuracy: 0.8846 - val_loss: 0.2861 - val_accuracy: 0.8863
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.2905 - accuracy: 0.8846 - val_loss: 0.2891 - val_accuracy: 0.8853
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.2909 - accuracy: 0.8843 - val_loss: 0.2882 - val_accuracy: 0.8858
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.2905 - accuracy: 0.8848 - val_loss: 0.2904 - val_accuracy: 0.8846
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.2894 - accuracy: 0.8848 - val_loss: 0.2924 - val_accuracy: 0.8838
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.2892 - accuracy: 0.8850 - val_loss: 0.2956 - val_accuracy: 0.8819

# %%
def predict(model, test_data):
    y_predictions = model.predict_classes(make_sliding_window(test_data['signal'], sliding_window_size))
    return pd.DataFrame({'time' : test_data['time'].values, 'open_channels' : y_predictions})

# %%
model1.save('NN_model1.h5')
model2.save('NN_model2.h5')
model3.save('NN_model3.h5')
model4.save('NN_model4.h5')
model5.save('NN_model5.h5')

# %%
predictions = pd.DataFrame(columns = ['time', 'open_channels'])
predictions = pd.concat([predictions, predict(model1, test_chunks[0])])
predictions = pd.concat([predictions, predict(model3, test_chunks[1])])
predictions = pd.concat([predictions, predict(model4, test_chunks[2])])
predictions = pd.concat([predictions, predict(model1, test_chunks[3])])
predictions = pd.concat([predictions, predict(model2, test_chunks[4])])
predictions = pd.concat([predictions, predict(model5, test_chunks[5])])
predictions = pd.concat([predictions, predict(model4, test_chunks[6])])
predictions = pd.concat([predictions, predict(model5, test_chunks[7])])
predictions = pd.concat([predictions, predict(model1, test_chunks[8])])
predictions = pd.concat([predictions, predict(model3, test_chunks[9])])
predictions = pd.concat([predictions, predict(model1, test_chunks[10])])
predictions = pd.concat([predictions, predict(model1, test_chunks[11])])
predictions = pd.concat([predictions, predict(model1, test_chunks[12])])
predictions = pd.concat([predictions, predict(model1, test_chunks[13])])
predictions = pd.concat([predictions, predict(model1, test_chunks[14])])
predictions = pd.concat([predictions, predict(model1, test_chunks[15])])
predictions = pd.concat([predictions, predict(model1, test_chunks[16])])
predictions = pd.concat([predictions, predict(model1, test_chunks[17])])
predictions = pd.concat([predictions, predict(model1, test_chunks[18])])
predictions = pd.concat([predictions, predict(model1, test_chunks[19])])

# %%
plt.figure(figsize = (20, 10))
plt.plot(predictions['time'], predictions['open_channels'].rolling(10000).mean() + 10)
for i in test_chunks:
    plt.plot(i['time'], i['signal'])

# %%
predictions.to_csv('~/Desktop/test_predictions2.csv', index = False, float_format='%.4f')
#0.937 preds_12
