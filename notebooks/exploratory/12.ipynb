# %%
import pandas as pd
import numpy as np
import math
import random
import matplotlib.pyplot as plt

import sys
import os
from os import listdir
from os.path import isfile, join
from tqdm import tqdm
import time

from sklearn.model_selection import train_test_split, KFold, GroupKFold
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier, StackingClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.metrics import f1_score, accuracy_score

from keras.models import Sequential
from keras.layers import Dense, Conv1D, MaxPooling1D, Dropout, LSTM
from keras.regularizers import l1, l2, l1_l2
from keras.models import load_model


module_path = os.path.abspath(os.path.join(os.pardir, os.pardir))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from src.transformers import LinearTransformation, ParabolicTransformation, TrigTransformation, MeanTransformer
from src.preprocessing import *
from src.sliding_window import *
from src.models import *

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2


# Global Var
sliding_window_size = 20
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
full_data = pd.read_csv('../../data/train.csv')
test_data = pd.read_csv('../../data/test.csv')

# %%
train_chunks = chunk_data(full_data, 10)

lt = LinearTransformation()
pt = ParabolicTransformation()
tt = TrigTransformation(trig_function = 'sin')

train_chunks[1].loc[train_chunks[1].index[:100000], 'signal'] = lt.fit_transform(train_chunks[1][:100000], 3/10, -15)
train_chunks[6]['signal'] = tt.fit_transform(train_chunks[6], 300, 50, 4.95)
train_chunks[7]['signal'] = tt.fit_transform(train_chunks[7], 350, 50, 5.030)
train_chunks[8]['signal'] = tt.fit_transform(train_chunks[8], 400, 50, 4.974)
train_chunks[9]['signal'] = tt.fit_transform(train_chunks[9], 450, 50, 5.089)

plt.figure(figsize = (20, 10))
for i in train_chunks:
    plt.plot(i['time'], i['signal'])

# %%
test_chunks = chunk_data(test_data, 4)
test_chunks = chunk_data(test_chunks[0], 5) + chunk_data(test_chunks[1], 5) + test_chunks[2:]

test_chunks[0]['signal'] = lt.fit_transform(test_chunks[0], 3 / 10, -150)
test_chunks[1]['signal'] = lt.fit_transform(test_chunks[1], 3 / 10, -153)
test_chunks[4]['signal'] = lt.fit_transform(test_chunks[4], 3 / 10, -162)
test_chunks[6]['signal'] = lt.fit_transform(test_chunks[6], 3 / 10, -168)
test_chunks[7]['signal'] = lt.fit_transform(test_chunks[7], 3 / 10, -171)
test_chunks[8]['signal'] = lt.fit_transform(test_chunks[8], 3 / 10, -174)
test_chunks[10]['signal'] = tt.fit_transform(test_chunks[10], 600, 50, 4.925)

test_chunks = test_chunks[:10] + chunk_data(pd.concat(test_chunks[10:]), 10)

plt.figure(figsize = (20, 10))
for i in test_chunks:
    plt.plot(i['time'], i['signal'])

# %%
mt = MeanTransformer().fit(0)

for chunk in train_chunks:
    chunk['signal'] = mt.transform(chunk['signal'])
    plt.plot(chunk['time'], chunk['signal'])
    
for chunk in test_chunks:
    chunk['signal'] = mt.transform(chunk['signal'])
    plt.plot(chunk['time'], chunk['signal'])

# %%
# def _sliding_window(array, window_size, offset = 0):
#     """
#     offset = number of zeros added to the begining 
#     """
#     array = np.append(np.append(np.zeros(offset), array), np.zeros(window_size - offset))
#     sliding_window_array = [array[0: -window_size]]
#     for i in range(1, window_size):
#         sliding_window_array = np.append(sliding_window_array, [array[i:i - window_size]], axis = 0)
#     return sliding_window_array.T

# def make_sliding_window(series, window_size):
#     col_names = [series.name + str(i) for i in range(window_size)]
#     return pd.DataFrame(_sliding_window(series, window_size, window_size // 2), columns = col_names)

# def make_sliding_window_frame(data, window_size):
#     sliding_window = make_sliding_window(data['signal'], window_size)
#     sliding_window['open_channels'] = data['open_channels'].reset_index(drop = True)
#     return sliding_window

# %%
def _model_architecture():
    model = Sequential()
    model.add(Dense(22, input_dim = sliding_window_size, activation = 'relu'))
    model.add(Dense(33, activation = 'relu'))
    model.add(Dense(44, activation = 'relu'))
    model.add(Dense(11, activation = 'softmax'))
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model


def _train_model(model, data, cycles = 5, epochs = 3):
    for _ in range(cycles):
        time.sleep(5)
        y = data['open_channels']
        X = data.drop(['open_channels'], axis = 1)
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.35)
        model.fit(X_train, y_train, batch_size = 100, epochs = epochs, validation_data = (X_test, y_test))

        
#'''
def get_model(data, train_model = True, cycles = 5, epochs = 3):
    model = _model_architecture()
    if train_model:
        _train_model(model, data, cycles = cycles, epochs = epochs)
    return model
#'''

'''
def get_model(data, time_window_size):
    model = Sequential()
    model.add(Conv1D(filters=128, kernel_size=5, padding='same', activation='relu',
                         input_shape=(time_window_size, 1)))
    model.add(MaxPooling1D(pool_size=5))
    model.add(Dense(units = time_window_size, activation='linear'))
    model.add(Dense(time_window_size * 2, activation = 'relu'))
    model.add(Dense(11, activation = 'softmax'))
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model
#'''

'''
def get_modelx(data, time_window_size):
    model = Sequential()
    model.add(LSTM(time_window_size * 10, input_shape  = (1, time_window_size)))
    model.add(Dense(40, activation = 'relu', kernel_regularizer = l2(0.01)))
    model.add(Dense(11, activation = 'softmax'))
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model
#''';

# %%
#model = get_model(model5_data, cycles = 20, epochs = 2)

# %% [markdown]
# y = model5_data['open_channels']
# X = model5_data.drop(['open_channels'], axis = 1)
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.35)
# model.fit(X_train, y_train, batch_size = 100, epochs = 3, validation_data = (X_test, y_test))

# %% [markdown]
# y = model5_data['open_channels']
# X = model5_data.drop(['open_channels'], axis = 1)
# X_train, X_test, y_train, y_test = train_test_split(X, y)
# model.fit(X_train, y_train, batch_size = 100, epochs = 3, validation_data = (X_test, y_test))

# %%
model1_data = pd.concat([train_chunks[0], train_chunks[1]])
model1_data = make_sliding_window_frame(model1_data, sliding_window_size)

model2_data = pd.concat([train_chunks[2], train_chunks[6]])
model2_data = make_sliding_window_frame(model2_data, sliding_window_size)

model3_data = pd.concat([train_chunks[3]])
# model3_data = pd.concat([train_chunks[3], train_chunks[7]])
model3_data = make_sliding_window_frame(model3_data, sliding_window_size)

model4_data = pd.concat([train_chunks[5], train_chunks[8]])
model4_data = make_sliding_window_frame(model4_data, sliding_window_size)

model5_data = pd.concat([train_chunks[4], train_chunks[9]])
model5_data = make_sliding_window_frame(model5_data, sliding_window_size)

# %%
model1 = get_model(model1_data, cycles = 8, epochs = 2)
print('\n\n')
time.sleep(300)
model2 = get_model(model2_data, cycles = 8, epochs = 2)
print('\n\n')
time.sleep(300)
model3 = get_model(model3_data, cycles = 10, epochs = 2)
print('\n\n')
time.sleep(300)
model4 = get_model(model4_data, cycles = 15, epochs = 2)
print('\n\n')
time.sleep(300)
model5 = get_model(model5_data, cycles = 20, epochs = 2)
# Out:
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 12us/step - loss: 0.0193 - accuracy: 0.9972 - val_loss: 0.0018 - val_accuracy: 0.9995
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0016 - val_accuracy: 0.9995
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0011 - val_accuracy: 0.9996
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.0012 - val_accuracy: 0.9996
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.0012 - val_accuracy: 0.9996
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.0013 - val_accuracy: 0.9996
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0016 - val_accuracy: 0.9995
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0015 - val_accuracy: 0.9996
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0012 - val_accuracy: 0.9996
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0012 - val_accuracy: 0.9996
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0017 - val_accuracy: 0.9995
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0013 - val_accuracy: 0.9996
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0011 - val_accuracy: 0.9996
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0013 - val_accuracy: 0.9996
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0013 - val_accuracy: 0.9996
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0011 - val_accuracy: 0.9997
#
#
#
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0230 - accuracy: 0.9938 - val_loss: 0.0080 - val_accuracy: 0.9972
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0079 - accuracy: 0.9973 - val_loss: 0.0079 - val_accuracy: 0.9973
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0077 - accuracy: 0.9973 - val_loss: 0.0080 - val_accuracy: 0.9972
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0075 - accuracy: 0.9974 - val_loss: 0.0074 - val_accuracy: 0.9975
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0074 - accuracy: 0.9974 - val_loss: 0.0072 - val_accuracy: 0.9975
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0073 - accuracy: 0.9974 - val_loss: 0.0073 - val_accuracy: 0.9975
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0072 - accuracy: 0.9975 - val_loss: 0.0072 - val_accuracy: 0.9973
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0071 - accuracy: 0.9975 - val_loss: 0.0083 - val_accuracy: 0.9971
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0071 - accuracy: 0.9975 - val_loss: 0.0067 - val_accuracy: 0.9976
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0070 - accuracy: 0.9975 - val_loss: 0.0071 - val_accuracy: 0.9975
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0069 - accuracy: 0.9976 - val_loss: 0.0069 - val_accuracy: 0.9976
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0068 - accuracy: 0.9976 - val_loss: 0.0071 - val_accuracy: 0.9976
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0069 - accuracy: 0.9976 - val_loss: 0.0068 - val_accuracy: 0.9976
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0068 - accuracy: 0.9976 - val_loss: 0.0065 - val_accuracy: 0.9977
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0067 - accuracy: 0.9977 - val_loss: 0.0072 - val_accuracy: 0.9976
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0066 - accuracy: 0.9977 - val_loss: 0.0068 - val_accuracy: 0.9976
#
#
#
# Train on 325000 samples, validate on 175000 samples
# Epoch 1/2
# 325000/325000 [==============================] - 4s 12us/step - loss: 0.1179 - accuracy: 0.9604 - val_loss: 0.0393 - val_accuracy: 0.9858
# Epoch 2/2
# 325000/325000 [==============================] - 4s 11us/step - loss: 0.0403 - accuracy: 0.9855 - val_loss: 0.0391 - val_accuracy: 0.9858
# Train on 325000 samples, validate on 175000 samples
# Epoch 1/2
# 325000/325000 [==============================] - 4s 11us/step - loss: 0.0378 - accuracy: 0.9863 - val_loss: 0.0360 - val_accuracy: 0.9869
# Epoch 2/2
# 325000/325000 [==============================] - 4s 11us/step - loss: 0.0369 - accuracy: 0.9866 - val_loss: 0.0405 - val_accuracy: 0.9852
# Train on 325000 samples, validate on 175000 samples
# Epoch 1/2
# 325000/325000 [==============================] - 4s 11us/step - loss: 0.0358 - accuracy: 0.9869 - val_loss: 0.0361 - val_accuracy: 0.9870
# Epoch 2/2
# 325000/325000 [==============================] - 4s 11us/step - loss: 0.0355 - accuracy: 0.9871 - val_loss: 0.0349 - val_accuracy: 0.9875
# Train on 325000 samples, validate on 175000 samples
# Epoch 1/2
# 325000/325000 [==============================] - 4s 11us/step - loss: 0.0354 - accuracy: 0.9872 - val_loss: 0.0362 - val_accuracy: 0.9872
# Epoch 2/2
# 325000/325000 [==============================] - 4s 11us/step - loss: 0.0354 - accuracy: 0.9871 - val_loss: 0.0352 - val_accuracy: 0.9873
# Train on 325000 samples, validate on 175000 samples
# Epoch 1/2
# 325000/325000 [==============================] - 4s 11us/step - loss: 0.0346 - accuracy: 0.9875 - val_loss: 0.0345 - val_accuracy: 0.9871
# Epoch 2/2
# 325000/325000 [==============================] - 4s 12us/step - loss: 0.0346 - accuracy: 0.9874 - val_loss: 0.0356 - val_accuracy: 0.9866
# Train on 325000 samples, validate on 175000 samples
# Epoch 1/2
# 325000/325000 [==============================] - 4s 11us/step - loss: 0.0347 - accuracy: 0.9873 - val_loss: 0.0339 - val_accuracy: 0.9875
# Epoch 2/2
# 325000/325000 [==============================] - 4s 11us/step - loss: 0.0344 - accuracy: 0.9876 - val_loss: 0.0340 - val_accuracy: 0.9876
# Train on 325000 samples, validate on 175000 samples
# Epoch 1/2
# 325000/325000 [==============================] - 4s 11us/step - loss: 0.0334 - accuracy: 0.9878 - val_loss: 0.0375 - val_accuracy: 0.9866
# Epoch 2/2
# 325000/325000 [==============================] - 4s 12us/step - loss: 0.0332 - accuracy: 0.9877 - val_loss: 0.0343 - val_accuracy: 0.9877
# Train on 325000 samples, validate on 175000 samples
# Epoch 1/2
# 325000/325000 [==============================] - 4s 12us/step - loss: 0.0338 - accuracy: 0.9876 - val_loss: 0.0347 - val_accuracy: 0.9873
# Epoch 2/2
# 325000/325000 [==============================] - 4s 11us/step - loss: 0.0334 - accuracy: 0.9877 - val_loss: 0.0339 - val_accuracy: 0.9876
# Train on 325000 samples, validate on 175000 samples
# Epoch 1/2
# 325000/325000 [==============================] - 4s 11us/step - loss: 0.0329 - accuracy: 0.9878 - val_loss: 0.0358 - val_accuracy: 0.9871
# Epoch 2/2
# 325000/325000 [==============================] - 4s 11us/step - loss: 0.0327 - accuracy: 0.9878 - val_loss: 0.0356 - val_accuracy: 0.9874
# Train on 325000 samples, validate on 175000 samples
# Epoch 1/2
# 325000/325000 [==============================] - 4s 11us/step - loss: 0.0335 - accuracy: 0.9877 - val_loss: 0.0328 - val_accuracy: 0.9880
# Epoch 2/2
# 325000/325000 [==============================] - 4s 11us/step - loss: 0.0331 - accuracy: 0.9879 - val_loss: 0.0328 - val_accuracy: 0.9879
#
#
#
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.1311 - accuracy: 0.9538 - val_loss: 0.0696 - val_accuracy: 0.9748
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0703 - accuracy: 0.9742 - val_loss: 0.0668 - val_accuracy: 0.9759
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0691 - accuracy: 0.9747 - val_loss: 0.0662 - val_accuracy: 0.9758
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0681 - accuracy: 0.9750 - val_loss: 0.0670 - val_accuracy: 0.9754
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0672 - accuracy: 0.9755 - val_loss: 0.0668 - val_accuracy: 0.9757
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0664 - accuracy: 0.9757 - val_loss: 0.0659 - val_accuracy: 0.9762
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0663 - accuracy: 0.9756 - val_loss: 0.0664 - val_accuracy: 0.9757
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0656 - accuracy: 0.9758 - val_loss: 0.0672 - val_accuracy: 0.9757
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0654 - accuracy: 0.9762 - val_loss: 0.0636 - val_accuracy: 0.9766
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0650 - accuracy: 0.9764 - val_loss: 0.0654 - val_accuracy: 0.9760
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0649 - accuracy: 0.9763 - val_loss: 0.0634 - val_accuracy: 0.9766
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0646 - accuracy: 0.9765 - val_loss: 0.0635 - val_accuracy: 0.9769
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0641 - accuracy: 0.9767 - val_loss: 0.0635 - val_accuracy: 0.9769
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0641 - accuracy: 0.9767 - val_loss: 0.0663 - val_accuracy: 0.9757
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0641 - accuracy: 0.9769 - val_loss: 0.0648 - val_accuracy: 0.9766
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0639 - accuracy: 0.9767 - val_loss: 0.0644 - val_accuracy: 0.9763
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0636 - accuracy: 0.9770 - val_loss: 0.0623 - val_accuracy: 0.9773
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0635 - accuracy: 0.9768 - val_loss: 0.0629 - val_accuracy: 0.9770
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 12us/step - loss: 0.0637 - accuracy: 0.9768 - val_loss: 0.0629 - val_accuracy: 0.9773
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0632 - accuracy: 0.9768 - val_loss: 0.0641 - val_accuracy: 0.9769
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0639 - accuracy: 0.9767 - val_loss: 0.0621 - val_accuracy: 0.9775
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0638 - accuracy: 0.9768 - val_loss: 0.0623 - val_accuracy: 0.9774
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0631 - accuracy: 0.9770 - val_loss: 0.0631 - val_accuracy: 0.9770
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0631 - accuracy: 0.9769 - val_loss: 0.0633 - val_accuracy: 0.9771
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0630 - accuracy: 0.9770 - val_loss: 0.0625 - val_accuracy: 0.9773
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0632 - accuracy: 0.9771 - val_loss: 0.0646 - val_accuracy: 0.9767
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0631 - accuracy: 0.9771 - val_loss: 0.0637 - val_accuracy: 0.9769
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0628 - accuracy: 0.9773 - val_loss: 0.0625 - val_accuracy: 0.9774
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0629 - accuracy: 0.9772 - val_loss: 0.0623 - val_accuracy: 0.9775
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.0629 - accuracy: 0.9771 - val_loss: 0.0624 - val_accuracy: 0.9773
#
#
#
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.3860 - accuracy: 0.8491 - val_loss: 0.3106 - val_accuracy: 0.8765
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.2976 - accuracy: 0.8815 - val_loss: 0.2965 - val_accuracy: 0.8829
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.2948 - accuracy: 0.8827 - val_loss: 0.2924 - val_accuracy: 0.8840
# Epoch 2/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.2932 - accuracy: 0.8836 - val_loss: 0.2882 - val_accuracy: 0.8858
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 12us/step - loss: 0.2923 - accuracy: 0.8838 - val_loss: 0.2878 - val_accuracy: 0.8859
# Epoch 2/2
# 650000/650000 [==============================] - 7s 12us/step - loss: 0.2909 - accuracy: 0.8843 - val_loss: 0.3063 - val_accuracy: 0.8787
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.2909 - accuracy: 0.8843 - val_loss: 0.2889 - val_accuracy: 0.8852
# Epoch 2/2
# 650000/650000 [==============================] - 7s 12us/step - loss: 0.2901 - accuracy: 0.8846 - val_loss: 0.2886 - val_accuracy: 0.8854
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.2890 - accuracy: 0.8852 - val_loss: 0.2903 - val_accuracy: 0.8843
# Epoch 2/2
# 650000/650000 [==============================] - 7s 11us/step - loss: 0.2886 - accuracy: 0.8854 - val_loss: 0.2899 - val_accuracy: 0.8843
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.2894 - accuracy: 0.8855 - val_loss: 0.2858 - val_accuracy: 0.8861
# Epoch 2/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.2891 - accuracy: 0.8852 - val_loss: 0.2906 - val_accuracy: 0.8846
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.2884 - accuracy: 0.8851 - val_loss: 0.2872 - val_accuracy: 0.8858
# Epoch 2/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.2879 - accuracy: 0.8857 - val_loss: 0.2869 - val_accuracy: 0.8862
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.2878 - accuracy: 0.8858 - val_loss: 0.2873 - val_accuracy: 0.8857
# Epoch 2/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.2875 - accuracy: 0.8857 - val_loss: 0.2914 - val_accuracy: 0.8835
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.2877 - accuracy: 0.8856 - val_loss: 0.2871 - val_accuracy: 0.8858
# Epoch 2/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.2873 - accuracy: 0.8854 - val_loss: 0.2874 - val_accuracy: 0.8857
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.2869 - accuracy: 0.8857 - val_loss: 0.2853 - val_accuracy: 0.8869
# Epoch 2/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.2866 - accuracy: 0.8858 - val_loss: 0.2873 - val_accuracy: 0.8861
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.2879 - accuracy: 0.8858 - val_loss: 0.2853 - val_accuracy: 0.8868
# Epoch 2/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.2877 - accuracy: 0.8853 - val_loss: 0.2838 - val_accuracy: 0.8871
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.2867 - accuracy: 0.8860 - val_loss: 0.2859 - val_accuracy: 0.8867
# Epoch 2/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.2867 - accuracy: 0.8860 - val_loss: 0.2881 - val_accuracy: 0.8859
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.2861 - accuracy: 0.8862 - val_loss: 0.2869 - val_accuracy: 0.8863
# Epoch 2/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.2859 - accuracy: 0.8863 - val_loss: 0.2857 - val_accuracy: 0.8862
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.2864 - accuracy: 0.8862 - val_loss: 0.2903 - val_accuracy: 0.8846
# Epoch 2/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.2860 - accuracy: 0.8863 - val_loss: 0.2851 - val_accuracy: 0.8869
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.2855 - accuracy: 0.8870 - val_loss: 0.2863 - val_accuracy: 0.8858
# Epoch 2/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.2852 - accuracy: 0.8869 - val_loss: 0.2888 - val_accuracy: 0.8853
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.2856 - accuracy: 0.8863 - val_loss: 0.2858 - val_accuracy: 0.8870
# Epoch 2/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.2855 - accuracy: 0.8868 - val_loss: 0.2857 - val_accuracy: 0.8863
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.2859 - accuracy: 0.8866 - val_loss: 0.2870 - val_accuracy: 0.8858
# Epoch 2/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.2860 - accuracy: 0.8864 - val_loss: 0.2859 - val_accuracy: 0.8867
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.2859 - accuracy: 0.8867 - val_loss: 0.2867 - val_accuracy: 0.8861
# Epoch 2/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.2859 - accuracy: 0.8867 - val_loss: 0.2864 - val_accuracy: 0.8862
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.2860 - accuracy: 0.8861 - val_loss: 0.2858 - val_accuracy: 0.8866
# Epoch 2/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.2855 - accuracy: 0.8863 - val_loss: 0.2871 - val_accuracy: 0.8858
# Train on 650000 samples, validate on 350000 samples
# Epoch 1/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.2853 - accuracy: 0.8868 - val_loss: 0.2855 - val_accuracy: 0.8864
# Epoch 2/2
# 650000/650000 [==============================] - 8s 12us/step - loss: 0.2851 - accuracy: 0.8869 - val_loss: 0.2887 - val_accuracy: 0.8850

# %%
def predict(model, test_data):
    y_predictions = model.predict_classes(make_sliding_window_series(test_data['signal'], sliding_window_size))
    return pd.DataFrame({'time' : test_data['time'].values, 'open_channels' : y_predictions})

# %%
predictions = pd.DataFrame(columns = ['time', 'open_channels'])
predictions = pd.concat([predictions, predict(model1, test_chunks[0])])
predictions = pd.concat([predictions, predict(model3, test_chunks[1])])
predictions = pd.concat([predictions, predict(model4, test_chunks[2])])
predictions = pd.concat([predictions, predict(model1, test_chunks[3])])
predictions = pd.concat([predictions, predict(model2, test_chunks[4])])
predictions = pd.concat([predictions, predict(model5, test_chunks[5])])
predictions = pd.concat([predictions, predict(model4, test_chunks[6])])
predictions = pd.concat([predictions, predict(model5, test_chunks[7])])
predictions = pd.concat([predictions, predict(model1, test_chunks[8])])
predictions = pd.concat([predictions, predict(model3, test_chunks[9])])
predictions = pd.concat([predictions, predict(model1, test_chunks[10])])
predictions = pd.concat([predictions, predict(model1, test_chunks[11])])
predictions = pd.concat([predictions, predict(model1, test_chunks[12])])
predictions = pd.concat([predictions, predict(model1, test_chunks[13])])
predictions = pd.concat([predictions, predict(model1, test_chunks[14])])
predictions = pd.concat([predictions, predict(model1, test_chunks[15])])
predictions = pd.concat([predictions, predict(model1, test_chunks[16])])
predictions = pd.concat([predictions, predict(model1, test_chunks[17])])
predictions = pd.concat([predictions, predict(model1, test_chunks[18])])
predictions = pd.concat([predictions, predict(model1, test_chunks[19])])

# %%
plt.figure(figsize = (20, 10))
plt.plot(predictions['time'], predictions['open_channels'].rolling(10000).mean() + 10)
for i in test_chunks:
    plt.plot(i['time'], i['signal'])

# %%
predictions.to_csv('~/Desktop/test_predictions2.csv', index = False, float_format='%.4f')
#0.937 preds_12

# %%
#preds = predictions.copy()

# %%
(preds.open_channels != predictions.open_channels).sum()
# Out:
# 453065

# %%
good_preds = pd.read_csv('~/Desktop/predictions/15_0.939_mean_transformed.csv')

# %%
(good_preds.open_channels.values != predictions.open_channels.values).sum()
# Out:
# 9125

# %%
make_sliding_window_series(test_chunks[0]['signal'], sliding_window_size)
# Out:
#         signal0   signal1   signal2   signal3   signal4   signal5   signal6  \
# 0      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000 -0.066306
# ...         ...       ...       ...       ...       ...       ...       ...
# 99995 -0.614056 -0.552586 -0.500916 -0.188546 -0.315776 -0.245106 -0.548536
# 99996 -0.552586 -0.500916 -0.188546 -0.315776 -0.245106 -0.548536 -0.500266
# 99997 -0.500916 -0.188546 -0.315776 -0.245106 -0.548536 -0.500266 -0.721096
# 99998 -0.188546 -0.315776 -0.245106 -0.548536 -0.500266 -0.721096 -0.498326
# 99999 -0.315776 -0.245106 -0.548536 -0.500266 -0.721096 -0.498326 -0.461556
#
#         signal7   signal8   signal9  signal10  signal11  signal12  signal13  \
# 0      0.000000  0.000000  0.000000 -0.066306 -0.265936 -0.276566  0.148404
# 1      0.000000  0.000000 -0.066306 -0.265936 -0.276566  0.148404 -0.032126
# 2      0.000000 -0.066306 -0.265936 -0.276566  0.148404 -0.032126  0.017444
# 3     -0.066306 -0.265936 -0.276566  0.148404 -0.032126  0.017444 -0.154486
# 4     -0.265936 -0.276566  0.148404 -0.032126  0.017444 -0.154486 -0.195516
# ...         ...       ...       ...       ...       ...       ...       ...
# 99995 -0.500266 -0.721096 -0.498326 -0.461556 -0.607686 -0.171916  0.266454
# 99996 -0.721096 -0.498326 -0.461556 -0.607686 -0.171916  0.266454  0.066424
# 99997 -0.498326 -0.461556 -0.607686 -0.171916  0.266454  0.066424  0.000000
# 99998 -0.461556 -0.607686 -0.171916  0.266454  0.066424  0.000000  0.000000
# 99999 -0.607686 -0.171916  0.266454  0.066424  0.000000  0.000000  0.000000
#
#        signal14  signal15  signal16  signal17  signal18  signal19
# 0     -0.032126  0.017444 -0.154486 -0.195516 -0.264546  0.207424
# 1      0.017444 -0.154486 -0.195516 -0.264546  0.207424 -0.355106
# 2     -0.154486 -0.195516 -0.264546  0.207424 -0.355106 -0.038536
# 3     -0.195516 -0.264546  0.207424 -0.355106 -0.038536 -0.328766
# 4     -0.264546  0.207424 -0.355106 -0.038536 -0.328766 -0.541896
# ...         ...       ...       ...       ...       ...       ...
# 99995  0.066424  0.000000  0.000000  0.000000  0.000000  0.000000
# 99996  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 99997  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 99998  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 99999  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
# [100000 rows x 20 columns]
